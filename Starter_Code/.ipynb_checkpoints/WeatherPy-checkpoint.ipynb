# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %%
# Set units
units = "metric"

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fale old settlement
# Processing Record 2 of Set 1 | ulsteinvik
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | vadso
# Processing Record 5 of Set 1 | honefoss
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | kamina
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | queenstown
# Processing Record 11 of Set 1 | manuguru
# Processing Record 12 of Set 1 | blackmans bay
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | llallagua
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | bilibino
# Processing Record 18 of Set 1 | papatowai
# Processing Record 19 of Set 1 | richards bay
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | oliver
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | chuhar jamali
# Processing Record 24 of Set 1 | san jose del cabo
# Processing Record 25 of Set 1 | gizo
# Processing Record 26 of Set 1 | adamstown
# Processing Record 27 of Set 1 | lorengau
# Processing Record 28 of Set 1 | itapipoca
# Processing Record 29 of Set 1 | santa ana
# Processing Record 30 of Set 1 | phan rang-thap cham
# Processing Record 31 of Set 1 | chos malal
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | nadym
# Processing Record 34 of Set 1 | edinburgh of the seven seas
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | whitehorse
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | ilulissat
# Processing Record 41 of Set 1 | siocon
# Processing Record 42 of Set 1 | puerto natales
# Processing Record 43 of Set 1 | russkaya polyana
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | al ghayzah
# Processing Record 47 of Set 1 | muynoq
# Processing Record 48 of Set 1 | qaqortoq
# Processing Record 49 of Set 1 | puerto aysen
# Processing Record 50 of Set 1 | utrik
# Processing Record 0 of Set 2 | weno
# Processing Record 1 of Set 2 | nemuro
# Processing Record 2 of Set 2 | black point
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | dunedin
# Processing Record 5 of Set 2 | faya-largeau
# Processing Record 6 of Set 2 | el nido
# Processing Record 7 of Set 2 | lu-uk
# Processing Record 8 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 9 of Set 2 | aur
# Processing Record 10 of Set 2 | fada
# Processing Record 11 of Set 2 | chonchi
# Processing Record 12 of Set 2 | kone
# Processing Record 13 of Set 2 | mejit
# Processing Record 14 of Set 2 | ad darb
# Processing Record 15 of Set 2 | taltal
# Processing Record 16 of Set 2 | ancud
# Processing Record 17 of Set 2 | gadzhiyevo
# Processing Record 18 of Set 2 | katsuura
# Processing Record 19 of Set 2 | mutare
# Processing Record 20 of Set 2 | north bend
# Processing Record 21 of Set 2 | tshabong
# Processing Record 22 of Set 2 | korsholm
# Processing Record 23 of Set 2 | west island
# Processing Record 24 of Set 2 | grytviken
# Processing Record 25 of Set 2 | kazerun
# Processing Record 26 of Set 2 | kuanda
# Processing Record 27 of Set 2 | badger
# Processing Record 28 of Set 2 | red oak
# Processing Record 29 of Set 2 | santo domingo zanatepec
# Processing Record 30 of Set 2 | quirinopolis
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | nar'yan-mar
# Processing Record 33 of Set 2 | port mathurin
# Processing Record 34 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 2 | sao joao da barra
# Processing Record 36 of Set 2 | lourdes
# Processing Record 37 of Set 2 | izazi
# Processing Record 38 of Set 2 | chibougamau
# Processing Record 39 of Set 2 | happy valley-goose bay
# Processing Record 40 of Set 2 | castries
# Processing Record 41 of Set 2 | margaret river
# Processing Record 42 of Set 2 | sechura
# Processing Record 43 of Set 2 | batroun
# Processing Record 44 of Set 2 | imperia
# Processing Record 45 of Set 2 | invercargill
# Processing Record 46 of Set 2 | nasiriyah
# Processing Record 47 of Set 2 | kenora
# Processing Record 48 of Set 2 | ciudad del carmen
# Processing Record 49 of Set 2 | el bauga
# Processing Record 0 of Set 3 | atafu village
# Processing Record 1 of Set 3 | isafjordur
# Processing Record 2 of Set 3 | borogontsy
# Processing Record 3 of Set 3 | sola
# Processing Record 4 of Set 3 | vila franca do campo
# Processing Record 5 of Set 3 | bandundu
# Processing Record 6 of Set 3 | saratamata
# City not found. Skipping...
# Processing Record 7 of Set 3 | olonkinbyen
# Processing Record 8 of Set 3 | kingston
# Processing Record 9 of Set 3 | alaghsas
# Processing Record 10 of Set 3 | santa cruz
# Processing Record 11 of Set 3 | san pedro pochutla
# Processing Record 12 of Set 3 | newman
# Processing Record 13 of Set 3 | marka
# Processing Record 14 of Set 3 | lihue
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | concepcion
# Processing Record 17 of Set 3 | acapulco de juarez
# Processing Record 18 of Set 3 | debre mark'os
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | bamboo flat
# Processing Record 21 of Set 3 | anadarko
# Processing Record 22 of Set 3 | sao jose da coroa grande
# Processing Record 23 of Set 3 | tralee
# Processing Record 24 of Set 3 | vorgashor
# Processing Record 25 of Set 3 | cartagena del chaira
# Processing Record 26 of Set 3 | kivioli
# Processing Record 27 of Set 3 | la passe
# Processing Record 28 of Set 3 | jinchang
# Processing Record 29 of Set 3 | college
# Processing Record 30 of Set 3 | morehead city
# Processing Record 31 of Set 3 | wailua homesteads
# Processing Record 32 of Set 3 | gebeit
# Processing Record 33 of Set 3 | the pas
# Processing Record 34 of Set 3 | makokou
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | valday
# Processing Record 37 of Set 3 | jamestown
# Processing Record 38 of Set 3 | byron bay
# Processing Record 39 of Set 3 | aasiaat
# Processing Record 40 of Set 3 | enewetak
# Processing Record 41 of Set 3 | emporia
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | bulawayo
# Processing Record 44 of Set 3 | diego de almagro
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 47 of Set 3 | albany
# Processing Record 48 of Set 3 | stanley
# Processing Record 49 of Set 3 | trn
# Processing Record 0 of Set 4 | sorong
# Processing Record 1 of Set 4 | malayer
# Processing Record 2 of Set 4 | anabar
# City not found. Skipping...
# Processing Record 3 of Set 4 | priob'ye
# Processing Record 4 of Set 4 | anadyr
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | warmbad
# Processing Record 7 of Set 4 | vilyuchinsk
# Processing Record 8 of Set 4 | tuy hoa
# Processing Record 9 of Set 4 | saldana
# Processing Record 10 of Set 4 | kirensk
# Processing Record 11 of Set 4 | oued zem
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | cabedelo
# Processing Record 14 of Set 4 | el calafate
# Processing Record 15 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 16 of Set 4 | saipan
# Processing Record 17 of Set 4 | gharghoda
# Processing Record 18 of Set 4 | papao
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | decorah
# Processing Record 21 of Set 4 | outapi
# City not found. Skipping...
# Processing Record 22 of Set 4 | sokcho
# Processing Record 23 of Set 4 | kourou
# Processing Record 24 of Set 4 | illizi
# Processing Record 25 of Set 4 | tolanaro
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | afaahiti
# Processing Record 28 of Set 4 | nefta
# Processing Record 29 of Set 4 | qa'en
# Processing Record 30 of Set 4 | port isabel
# Processing Record 31 of Set 4 | ekuvukeni
# Processing Record 32 of Set 4 | harper
# Processing Record 33 of Set 4 | segou
# Processing Record 34 of Set 4 | sesheke
# Processing Record 35 of Set 4 | dunn
# Processing Record 36 of Set 4 | nova sintra
# Processing Record 37 of Set 4 | hawaiian paradise park
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | kansk
# Processing Record 40 of Set 4 | plymouth
# Processing Record 41 of Set 4 | laguna
# Processing Record 42 of Set 4 | nkurenkuru
# City not found. Skipping...
# Processing Record 43 of Set 4 | cannonvale
# Processing Record 44 of Set 4 | melekeok village
# Processing Record 45 of Set 4 | nuku'alofa
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | bahia de caraquez
# Processing Record 48 of Set 4 | hammerfest
# Processing Record 49 of Set 4 | port lincoln
# Processing Record 0 of Set 5 | puerto madryn
# Processing Record 1 of Set 5 | tunceli
# Processing Record 2 of Set 5 | takayama
# Processing Record 3 of Set 5 | flying fish cove
# Processing Record 4 of Set 5 | tumayr
# Processing Record 5 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 5 | pisco
# Processing Record 7 of Set 5 | bazarnyye mataki
# Processing Record 8 of Set 5 | huanren
# Processing Record 9 of Set 5 | st. john's
# Processing Record 10 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 11 of Set 5 | nuuk
# Processing Record 12 of Set 5 | la ronge
# Processing Record 13 of Set 5 | sisimiut
# Processing Record 14 of Set 5 | nadi
# Processing Record 15 of Set 5 | bargaal
# Processing Record 16 of Set 5 | kaoma
# Processing Record 17 of Set 5 | garissa
# Processing Record 18 of Set 5 | chul'man
# Processing Record 19 of Set 5 | nyala
# Processing Record 20 of Set 5 | tura
# Processing Record 21 of Set 5 | haiku-pauwela
# Processing Record 22 of Set 5 | port-vila
# Processing Record 23 of Set 5 | ormara
# Processing Record 24 of Set 5 | makamba
# Processing Record 25 of Set 5 | al kharijah
# Processing Record 26 of Set 5 | wewak
# Processing Record 27 of Set 5 | lamesa
# Processing Record 28 of Set 5 | guerrero negro
# Processing Record 29 of Set 5 | iskateley
# Processing Record 30 of Set 5 | zuwarah
# Processing Record 31 of Set 5 | begun
# Processing Record 32 of Set 5 | puma
# Processing Record 33 of Set 5 | tazovsky
# Processing Record 34 of Set 5 | isle of lewis
# City not found. Skipping...
# Processing Record 35 of Set 5 | aykhal
# Processing Record 36 of Set 5 | yarkovo
# Processing Record 37 of Set 5 | namibe
# Processing Record 38 of Set 5 | broome
# Processing Record 39 of Set 5 | chinchilla
# Processing Record 40 of Set 5 | nizhnesortymskiy
# Processing Record 41 of Set 5 | inhambane
# Processing Record 42 of Set 5 | new norfolk
# Processing Record 43 of Set 5 | burg bei magdeburg
# Processing Record 44 of Set 5 | sarandi del yi
# Processing Record 45 of Set 5 | mahibadhoo
# Processing Record 46 of Set 5 | mengcheng chengguanzhen
# Processing Record 47 of Set 5 | genhe
# Processing Record 48 of Set 5 | viqueque
# Processing Record 49 of Set 5 | heihe
# Processing Record 0 of Set 6 | lata
# Processing Record 1 of Set 6 | villa yapacani
# Processing Record 2 of Set 6 | as sulayyil
# Processing Record 3 of Set 6 | merizo village
# Processing Record 4 of Set 6 | sumbawa besar
# Processing Record 5 of Set 6 | hovd
# Processing Record 6 of Set 6 | la mira
# Processing Record 7 of Set 6 | lae
# Processing Record 8 of Set 6 | bushland beach
# City not found. Skipping...
# Processing Record 9 of Set 6 | sarankhola
# Processing Record 10 of Set 6 | engel's
# Processing Record 11 of Set 6 | hithadhoo
# Processing Record 12 of Set 6 | dudinka
# Processing Record 13 of Set 6 | calvinia
# Processing Record 14 of Set 6 | sitka
# Processing Record 15 of Set 6 | daru
# Processing Record 16 of Set 6 | ust'-ilimsk
# Processing Record 17 of Set 6 | carovigno
# Processing Record 18 of Set 6 | miami beach
# Processing Record 19 of Set 6 | crane
# Processing Record 20 of Set 6 | luau
# Processing Record 21 of Set 6 | tianpeng
# Processing Record 22 of Set 6 | nabire
# Processing Record 23 of Set 6 | zarghun shahr
# Processing Record 24 of Set 6 | kimbe
# Processing Record 25 of Set 6 | wanning
# Processing Record 26 of Set 6 | quellon
# Processing Record 27 of Set 6 | badr hunayn
# Processing Record 28 of Set 6 | semirara
# Processing Record 29 of Set 6 | zaysan
# Processing Record 30 of Set 6 | vernon
# Processing Record 31 of Set 6 | keflavik
# Processing Record 32 of Set 6 | punta arenas
# Processing Record 33 of Set 6 | extrema
# Processing Record 34 of Set 6 | balsas
# Processing Record 35 of Set 6 | sultanah
# Processing Record 36 of Set 6 | lapithos
# Processing Record 37 of Set 6 | huayin
# Processing Record 38 of Set 6 | bel ombre
# Processing Record 39 of Set 6 | porto belo
# Processing Record 40 of Set 6 | uturoa
# Processing Record 41 of Set 6 | yazman
# Processing Record 42 of Set 6 | constantia
# Processing Record 43 of Set 6 | margate
# Processing Record 44 of Set 6 | la'ie
# Processing Record 45 of Set 6 | kerikeri
# Processing Record 46 of Set 6 | manado
# Processing Record 47 of Set 6 | ascension
# Processing Record 48 of Set 6 | polyarnyy
# Processing Record 49 of Set 6 | muntok
# Processing Record 0 of Set 7 | hasaki
# Processing Record 1 of Set 7 | ust-nera
# Processing Record 2 of Set 7 | midvagur
# Processing Record 3 of Set 7 | carnarvon
# Processing Record 4 of Set 7 | fallsburg
# Processing Record 5 of Set 7 | mount gambier
# Processing Record 6 of Set 7 | poronaysk
# Processing Record 7 of Set 7 | rikaze
# Processing Record 8 of Set 7 | eraan
# Processing Record 9 of Set 7 | fernie
# Processing Record 10 of Set 7 | maneromango
# Processing Record 11 of Set 7 | kavaratti
# Processing Record 12 of Set 7 | berezovo
# Processing Record 13 of Set 7 | ranchettes
# Processing Record 14 of Set 7 | yarmouth
# Processing Record 15 of Set 7 | susuman
# Processing Record 16 of Set 7 | acarau
# Processing Record 17 of Set 7 | clodomira
# Processing Record 18 of Set 7 | aswan
# Processing Record 19 of Set 7 | bubaque
# Processing Record 20 of Set 7 | klyuchi
# Processing Record 21 of Set 7 | tingi
# Processing Record 22 of Set 7 | harstad
# Processing Record 23 of Set 7 | achit
# Processing Record 24 of Set 7 | labytnangi
# Processing Record 25 of Set 7 | padangsidempuan
# Processing Record 26 of Set 7 | motygino
# Processing Record 27 of Set 7 | olyokminsk
# Processing Record 28 of Set 7 | colchani
# Processing Record 29 of Set 7 | vila velha
# Processing Record 30 of Set 7 | san julian
# Processing Record 31 of Set 7 | la sarre
# Processing Record 32 of Set 7 | wimauma
# Processing Record 33 of Set 7 | burela de cabo
# Processing Record 34 of Set 7 | guajara mirim
# Processing Record 35 of Set 7 | duki
# Processing Record 36 of Set 7 | funadhoo
# Processing Record 37 of Set 7 | magadi
# Processing Record 38 of Set 7 | reggane
# Processing Record 39 of Set 7 | remire-montjoly
# Processing Record 40 of Set 7 | al jawf
# Processing Record 41 of Set 7 | sittwe
# Processing Record 42 of Set 7 | puerto yuca
# Processing Record 43 of Set 7 | anna regina
# Processing Record 44 of Set 7 | jiazi
# Processing Record 45 of Set 7 | zonguldak
# Processing Record 46 of Set 7 | sierra grande
# Processing Record 47 of Set 7 | marsabit
# Processing Record 48 of Set 7 | codo
# Processing Record 49 of Set 7 | brookings
# Processing Record 0 of Set 8 | zvishavane
# Processing Record 1 of Set 8 | tamandare
# Processing Record 2 of Set 8 | khovd
# Processing Record 3 of Set 8 | khlevnoye
# Processing Record 4 of Set 8 | tucupita
# Processing Record 5 of Set 8 | fort bragg
# Processing Record 6 of Set 8 | mitu
# Processing Record 7 of Set 8 | tismana
# Processing Record 8 of Set 8 | merritt island
# Processing Record 9 of Set 8 | island harbour
# Processing Record 10 of Set 8 | yaring
# Processing Record 11 of Set 8 | almeirim
# Processing Record 12 of Set 8 | petauke
# Processing Record 13 of Set 8 | newport
# Processing Record 14 of Set 8 | idri
# Processing Record 15 of Set 8 | xiongzhou
# Processing Record 16 of Set 8 | sinop
# Processing Record 17 of Set 8 | conselheiro pena
# Processing Record 18 of Set 8 | san martin
# Processing Record 19 of Set 8 | mammoth lakes
# Processing Record 20 of Set 8 | chui
# Processing Record 21 of Set 8 | kargasok
# Processing Record 22 of Set 8 | kailua-kona
# Processing Record 23 of Set 8 | tromso
# Processing Record 24 of Set 8 | maumere
# Processing Record 25 of Set 8 | rio grande
# Processing Record 26 of Set 8 | manaure
# Processing Record 27 of Set 8 | puyang chengguanzhen
# Processing Record 28 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 29 of Set 8 | bekobod
# Processing Record 30 of Set 8 | codrington
# Processing Record 31 of Set 8 | zabid
# Processing Record 32 of Set 8 | castlegar
# Processing Record 33 of Set 8 | saynshand
# Processing Record 34 of Set 8 | timimoun
# Processing Record 35 of Set 8 | spring creek
# Processing Record 36 of Set 8 | calatayud
# Processing Record 37 of Set 8 | tazacorte
# Processing Record 38 of Set 8 | laojunmiao
# Processing Record 39 of Set 8 | nova vicosa
# Processing Record 40 of Set 8 | coquimbo
# Processing Record 41 of Set 8 | carauari
# Processing Record 42 of Set 8 | naha
# Processing Record 43 of Set 8 | mantua
# Processing Record 44 of Set 8 | greenville
# Processing Record 45 of Set 8 | mahina
# Processing Record 46 of Set 8 | bayganin
# Processing Record 47 of Set 8 | egilsstadir
# Processing Record 48 of Set 8 | aniva
# Processing Record 49 of Set 8 | tongliao
# Processing Record 0 of Set 9 | rangsdorf
# Processing Record 1 of Set 9 | gueltat zemmour
# City not found. Skipping...
# Processing Record 2 of Set 9 | mount isa
# Processing Record 3 of Set 9 | kampene
# Processing Record 4 of Set 9 | kharp
# Processing Record 5 of Set 9 | smolyaninovo
# Processing Record 6 of Set 9 | asikkala
# Processing Record 7 of Set 9 | qal'at bishah
# City not found. Skipping...
# Processing Record 8 of Set 9 | port-cartier
# Processing Record 9 of Set 9 | karratha
# Processing Record 10 of Set 9 | ketchikan
# Processing Record 11 of Set 9 | puerto armuelles
# Processing Record 12 of Set 9 | balaipungut
# Processing Record 13 of Set 9 | erdenet
# Processing Record 14 of Set 9 | pedernales
# Processing Record 15 of Set 9 | chibuto
# Processing Record 16 of Set 9 | ushtobe
# Processing Record 17 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 9 | oranjemund
# Processing Record 19 of Set 9 | kapa'a
# Processing Record 20 of Set 9 | morro do chapeu
# Processing Record 21 of Set 9 | turpan
# Processing Record 22 of Set 9 | bernardo de irigoyen
# Processing Record 23 of Set 9 | mohammedia
# Processing Record 24 of Set 9 | prado
# Processing Record 25 of Set 9 | abraham's bay
# City not found. Skipping...
# Processing Record 26 of Set 9 | saint-philippe
# Processing Record 27 of Set 9 | san antonio de pale
# Processing Record 28 of Set 9 | bikenibeu village
# Processing Record 29 of Set 9 | powell river
# Processing Record 30 of Set 9 | jining
# Processing Record 31 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 33 of Set 9 | saudarkrokur
# Processing Record 34 of Set 9 | san agustin de valle fertil
# Processing Record 35 of Set 9 | tutoia
# Processing Record 36 of Set 9 | minas de marcona
# Processing Record 37 of Set 9 | diamantino
# Processing Record 38 of Set 9 | zhangjiakou shi xuanhua qu
# Processing Record 39 of Set 9 | luderitz
# Processing Record 40 of Set 9 | muravlenko
# Processing Record 41 of Set 9 | gniezno
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | turtas
# Processing Record 44 of Set 9 | saint-felicien
# Processing Record 45 of Set 9 | aranda de duero
# Processing Record 46 of Set 9 | mili
# Processing Record 47 of Set 9 | okhotsk
# Processing Record 48 of Set 9 | christies beach
# Processing Record 49 of Set 9 | urengoy
# Processing Record 0 of Set 10 | amble
# Processing Record 1 of Set 10 | shubarkuduk
# Processing Record 2 of Set 10 | sandnessjoen
# Processing Record 3 of Set 10 | nichinan
# Processing Record 4 of Set 10 | kuah
# Processing Record 5 of Set 10 | buldana
# Processing Record 6 of Set 10 | barcelos
# Processing Record 7 of Set 10 | gaya
# Processing Record 8 of Set 10 | yeed
# Processing Record 9 of Set 10 | malinyi
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | pacific grove
# Processing Record 12 of Set 10 | armacao de buzios
# Processing Record 13 of Set 10 | barrington
# Processing Record 14 of Set 10 | essaouira
# Processing Record 15 of Set 10 | boom
# Processing Record 16 of Set 10 | raduzhny
# Processing Record 17 of Set 10 | rongelap
# Processing Record 18 of Set 10 | phalaborwa
# Processing Record 19 of Set 10 | arish
# Processing Record 20 of Set 10 | isiro
# Processing Record 21 of Set 10 | bhamo
# Processing Record 22 of Set 10 | songadh
# Processing Record 23 of Set 10 | greymouth
# Processing Record 24 of Set 10 | harnosand
# Processing Record 25 of Set 10 | holualoa
# Processing Record 26 of Set 10 | salavan
# Processing Record 27 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 28 of Set 10 | kachug
# Processing Record 29 of Set 10 | obock
# Processing Record 30 of Set 10 | beaufort west
# Processing Record 31 of Set 10 | patnanungan
# Processing Record 32 of Set 10 | phillip island
# Processing Record 33 of Set 10 | udachny
# Processing Record 34 of Set 10 | xilin hot
# Processing Record 35 of Set 10 | hoyland nether
# Processing Record 36 of Set 10 | port saint john's
# Processing Record 37 of Set 10 | kununurra
# Processing Record 38 of Set 10 | copala
# Processing Record 39 of Set 10 | cockburn town
# Processing Record 40 of Set 10 | hadibu
# Processing Record 41 of Set 10 | cukai
# Processing Record 42 of Set 10 | marsh harbour
# Processing Record 43 of Set 10 | sananduva
# Processing Record 44 of Set 10 | fortuna
# Processing Record 45 of Set 10 | playa del ingles
# Processing Record 46 of Set 10 | kapuskasing
# Processing Record 47 of Set 10 | chimoio
# Processing Record 48 of Set 10 | gamay
# Processing Record 49 of Set 10 | kolonia town
# Processing Record 0 of Set 11 | vangaindrano
# Processing Record 1 of Set 11 | calvia
# Processing Record 2 of Set 11 | kamaishi
# Processing Record 3 of Set 11 | prince rupert
# Processing Record 4 of Set 11 | colonel hill
# Processing Record 5 of Set 11 | palmas
# Processing Record 6 of Set 11 | mount pearl
# Processing Record 7 of Set 11 | talakan
# Processing Record 8 of Set 11 | alofi
# Processing Record 9 of Set 11 | postmasburg
# City not found. Skipping...
# Processing Record 10 of Set 11 | hirara
# Processing Record 11 of Set 11 | taro
# Processing Record 12 of Set 11 | juan griego
# Processing Record 13 of Set 11 | kilinochchi
# Processing Record 14 of Set 11 | pangkalpinang
# Processing Record 15 of Set 11 | nantucket
# Processing Record 16 of Set 11 | shingu
# Processing Record 17 of Set 11 | kolonia
# Processing Record 18 of Set 11 | kayyerkan
# Processing Record 19 of Set 11 | checker hall
# City not found. Skipping...
# Processing Record 20 of Set 11 | ciudad lazaro cardenas
# Processing Record 21 of Set 11 | yuzhno-kurilsk
# Processing Record 22 of Set 11 | pathein
# Processing Record 23 of Set 11 | abu jibeha
# Processing Record 24 of Set 11 | gaiman
# Processing Record 25 of Set 11 | carsamba
# Processing Record 26 of Set 11 | fonadhoo
# City not found. Skipping...
# Processing Record 27 of Set 11 | jinghong
# Processing Record 28 of Set 11 | port-saint-louis-du-rhone
# Processing Record 29 of Set 11 | ha'il
# Processing Record 30 of Set 11 | irece
# Processing Record 31 of Set 11 | rudnichnyy
# Processing Record 32 of Set 11 | oyama
# Processing Record 33 of Set 11 | kyzyl-burun
# City not found. Skipping...
# Processing Record 34 of Set 11 | machico
# Processing Record 35 of Set 11 | ashburton
# Processing Record 36 of Set 11 | fannuj
# City not found. Skipping...
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | westport
# Processing Record 39 of Set 11 | cozumel
# Processing Record 40 of Set 11 | odda
# Processing Record 41 of Set 11 | paka
# Processing Record 42 of Set 11 | greenwood
# Processing Record 43 of Set 11 | hobyo
# Processing Record 44 of Set 11 | arzachena
# Processing Record 45 of Set 11 | namsos
# Processing Record 46 of Set 11 | seaside
# Processing Record 47 of Set 11 | torghay
# Processing Record 48 of Set 11 | carinhanha
# Processing Record 49 of Set 11 | cheremukhovo
# Processing Record 0 of Set 12 | lalibela
# Processing Record 1 of Set 12 | south hedland
# Processing Record 2 of Set 12 | san rafael
# Processing Record 3 of Set 12 | bonthe
# Processing Record 4 of Set 12 | parnamirim
# Processing Record 5 of Set 12 | port augusta
# Processing Record 6 of Set 12 | kutum
# Processing Record 7 of Set 12 | dali
# Processing Record 8 of Set 12 | lianran
# Processing Record 9 of Set 12 | yaguara
# Processing Record 10 of Set 12 | brokopondo
# Processing Record 11 of Set 12 | mugia
# Processing Record 12 of Set 12 | muridke
# Processing Record 13 of Set 12 | talitsy
# Processing Record 14 of Set 12 | howrah
# Processing Record 15 of Set 12 | takamatsu
# Processing Record 16 of Set 12 | bogo
# Processing Record 17 of Set 12 | tocopilla
# Processing Record 18 of Set 12 | puerto carreno
# Processing Record 19 of Set 12 | kurtamysh
# Processing Record 20 of Set 12 | kagal
# Processing Record 21 of Set 12 | arrifes
# Processing Record 22 of Set 12 | veinticinco de mayo
# Processing Record 23 of Set 12 | marang
# Processing Record 24 of Set 12 | kyzyl-kyya
# Processing Record 25 of Set 12 | okha
# Processing Record 26 of Set 12 | campo gallo
# Processing Record 27 of Set 12 | kavieng
# Processing Record 28 of Set 12 | derzhavinsk
# Processing Record 29 of Set 12 | kalix
# Processing Record 30 of Set 12 | birao
# Processing Record 31 of Set 12 | magadan
# Processing Record 32 of Set 12 | ocean pointe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  fale old settlement  -9.3852 -171.2468     28.57        73          17
# 1           ulsteinvik  62.3432    5.8487      9.86        80         100
# 2             waitangi -43.9535 -176.5597      8.79        80           4
# 3                vadso  70.0744   29.7487      1.09        93          75
# 4             honefoss  60.1680   10.2565      1.45        90          74
#
#    Wind Speed Country        Date
# 0        7.03      TK  1731394551
# 1        0.89      NO  1731394552
# 2        5.08      NZ  1731394553
# 3        4.63      NO  1731394554
# 4        0.72      NO  1731394286

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_graph = city_data_df["Lat"]
max_tempsgraph = city_data_df["Max Temp"]
plt.scatter(lat_graph,max_tempsgraph,label="Cities")

# Incorporate the other graph properties
plt.title(f"Latitude vs. Max Temperature ")
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_graph = city_data_df["Lat"]
humidity_graph = city_data_df["Humidity"]
plt.scatter(lat_graph,humidity_graph,label="Cities")
# Incorporate the other graph properties
plt.title(f"Latitude vs. Humidity ")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
# Save the figure

plt.savefig("output_data/Fig2.png")

# Show plot

plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_graph = city_data_df["Lat"]
cloudiness_graph = city_data_df["Cloudiness"]
plt.scatter(lat_graph,cloudiness_graph,label="Cities")

# Incorporate the other graph properties
plt.title(f"Latitude vs. Humidity ")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_graph = city_data_df["Lat"]
windspeed_graph = city_data_df["Wind Speed"]
plt.scatter(lat_graph,windspeed_graph,label="Cities")

# Incorporate the other graph properties
plt.title(f"Latitude vs. Humidity ")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)   
    regress_values = x_values * slope + intercept
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]
plot_linear_regression(x_values, y_values, title=
'Linear Regression on the Northern Hemisphere for Maximum Temperature', y_label='Max Temp', text_coordinates=(0,0))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]
plot_linear_regression(x_values, y_values, title=
'Linear Regression on the Northern Hemisphere for Maximum Temperature', y_label='Max Temp', text_coordinates=(0,0))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]
plot_linear_regression(x_values, y_values, title=
'Linear Regression on the Northern Hemisphere for Maximum Temperature', y_label='Humidity', text_coordinates=(0,0))

# %%
# Southern Hemisphere
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]
plot_linear_regression(x_values, y_values, title=
'Linear Regression on the Northern Hemisphere for Maximum Temperature', y_label='Humidity', text_coordinates=(0,0))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]
plot_linear_regression(x_values, y_values, title=
'Linear Regression on the Northern Hemisphere for Maximum Temperature', y_label='Cloudiness', text_coordinates=(0,0))

# %%
# Southern Hemisphere
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]
plot_linear_regression(x_values, y_values, title=
'Linear Regression on the Northern Hemisphere for Maximum Temperature', y_label='Cloudiness', text_coordinates=(0,0))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
